# %% [markdown]
# ### Convert RealSense .bag → MP4

# %%
import numpy as np
import pyrealsense2 as rs
import cv2

def bag_to_mp4(bag_path: str, out_path: str, fps: float = 30.0):
    """
    Read a RealSense .bag file and write out a color-only MP4.
    """
    pipeline = rs.pipeline()
    cfg = rs.config()
    cfg.enable_device_from_file(bag_path, repeat_playback=False)
    profile = pipeline.start(cfg)

    # get color stream resolution
    color_stream = profile.get_stream(rs.stream.color).as_video_stream_profile()
    w, h = color_stream.width(), color_stream.height()

    # set up VideoWriter (mp4v codec)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(out_path, fourcc, fps, (w, h))

    try:
        while True:
            frames = pipeline.wait_for_frames()
            color = frames.get_color_frame()
            if not color:
                continue
            # convert to numpy array (RGB)
            img_rgb = np.asanyarray(color.get_data())
            # convert RGB→BGR for correct colors in OpenCV
            img_bgr = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR)
            writer.write(img_bgr)
    except RuntimeError:
        # bag playback ended
        pass
    finally:
        writer.release()
        pipeline.stop()
        print(f"✅ Wrote {out_path}")

# %% [markdown]
# ### Run conversion

# %%
import os

input_folder = "ros_bags/2nd_batch"  # replace with your folder containing .bag files
output_folder = "ros_bags/2nd_batch_converted"      # replace with your desired output folder
fps = 30.0                           # set your desired fps

os.makedirs(output_folder, exist_ok=True)

for fname in os.listdir(input_folder):
    if fname.endswith(".bag"):
        bag_file = os.path.join(input_folder, fname)
        output_mp4 = os.path.join(output_folder, os.path.splitext(fname)[0] + ".mp4")
        bag_to_mp4(bag_file, output_mp4, fps)
# Out:
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155234.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155333.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155749.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_153521.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_153723.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155117.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_154227.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_160032.mp4

# %% [markdown]
# ### View annotated Video

# %%
#!/usr/bin/env python3
import cv2
import subprocess
from ultralytics import YOLO
import sys

# ─── ADJUST THESE ───────────────────────────────────────────────────────────────
MODEL_PATH   = "../src/human_detector/models/best.pt"
# MODEL_PATH   = "../src/human_detector/models/best_v2_yolov11n.pt"
SOURCE_VIDEO = "converted_mp4_videos/2nd_batch_converted/robots_humans_side_2.mp4"
# ───────────────────────────────────────────────────────────────────────────────

def main():
    model = YOLO(MODEL_PATH)

    cap = cv2.VideoCapture(SOURCE_VIDEO)
    if not cap.isOpened():
        print(f"Error: cannot open {SOURCE_VIDEO}")
        sys.exit(1)

    fps    = cap.get(cv2.CAP_PROP_FPS) or 25
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    ffplay_cmd = [
        "ffplay",
        "-f", "rawvideo",
        "-pixel_format", "bgr24",
        "-video_size", f"{width}x{height}",
        "-framerate", str(int(fps)),
        "-autoexit",
        "-i", "-"
    ]

    try:
        proc = subprocess.Popen(ffplay_cmd, stdin=subprocess.PIPE, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    except FileNotFoundError:
        print("Error: ffplay not found. Install ffmpeg/ffplay.")
        cap.release()
        sys.exit(1)

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            results = model(frame)[0]
            boxes   = results.boxes.xyxy.cpu().numpy()
            confs   = results.boxes.conf.cpu().numpy()
            classes = results.boxes.cls.cpu().numpy()

            for (x1, y1, x2, y2), conf, cls in zip(boxes, confs, classes):
                x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
                name = model.names[int(cls)]
                score = conf.item()
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
                cv2.putText(frame, f"{name} {score:.2f}", (x1, y1-10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)

            proc.stdin.write(frame.tobytes())

        cap.release()
        proc.stdin.close()
        proc.wait()

    except KeyboardInterrupt:
        cap.release()
        proc.stdin.close()
        proc.wait()

if __name__ == "__main__":
    main()
# Out:
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.2ms
# Speed: 1.4ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 5.2ms
# Speed: 0.8ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.7ms
# Speed: 0.7ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 10.5ms
# Speed: 2.6ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 28.4ms
# Speed: 8.0ms preprocess, 28.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.7ms
# Speed: 3.1ms preprocess, 19.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.8ms
# Speed: 3.4ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.6ms
# Speed: 1.6ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.6ms
# Speed: 3.8ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 18.3ms
# Speed: 3.7ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 20.0ms
# Speed: 3.8ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 22.2ms
# Speed: 4.3ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 16.6ms
# Speed: 4.2ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.2ms
# Speed: 3.5ms preprocess, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 7.0ms
# Speed: 1.1ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 12.1ms
# Speed: 3.7ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 25.5ms
# Speed: 2.6ms preprocess, 25.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 15.0ms
# Speed: 4.5ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 6.4ms
# Speed: 3.1ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 22.7ms
# Speed: 4.3ms preprocess, 22.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 11.7ms
# Speed: 3.4ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 12.0ms
# Speed: 4.7ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.6ms
# Speed: 3.8ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 12.2ms
# Speed: 3.9ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 9.5ms
# Speed: 2.9ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 13.3ms
# Speed: 4.4ms preprocess, 13.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 14.2ms
# Speed: 4.3ms preprocess, 14.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 23.9ms
# Speed: 5.8ms preprocess, 23.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.9ms
# Speed: 4.9ms preprocess, 17.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.1ms
# Speed: 4.2ms preprocess, 17.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 66.5ms
# Speed: 11.3ms preprocess, 66.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.3ms
# Speed: 4.4ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 17.1ms
# Speed: 4.5ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 11.9ms
# Speed: 4.6ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 11.9ms
# Speed: 3.6ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 19.3ms
# Speed: 4.3ms preprocess, 19.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 15.9ms
# Speed: 4.1ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 33.0ms
# Speed: 4.6ms preprocess, 33.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 17.7ms
# Speed: 6.1ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 12.2ms
# Speed: 2.8ms preprocess, 12.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 19.3ms
# Speed: 3.7ms preprocess, 19.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 22.3ms
# Speed: 3.7ms preprocess, 22.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 17.0ms
# Speed: 4.4ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 14.7ms
# Speed: 3.6ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 11.9ms
# Speed: 3.5ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 21.7ms
# Speed: 3.2ms preprocess, 21.7ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 12.2ms
# Speed: 3.3ms preprocess, 12.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 24.7ms
# Speed: 4.2ms preprocess, 24.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 4 telecos, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 16.9ms
# Speed: 4.2ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 14.6ms
# Speed: 1.8ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 12.0ms
# Speed: 4.4ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 25.7ms
# Speed: 7.9ms preprocess, 25.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.4ms
# Speed: 0.7ms preprocess, 5.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 telecos, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 14.9ms
# Speed: 2.8ms preprocess, 14.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 17.0ms
# Speed: 2.6ms preprocess, 17.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 11.8ms
# Speed: 3.0ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 14.6ms
# Speed: 4.7ms preprocess, 14.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 20.2ms
# Speed: 3.5ms preprocess, 20.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 15.0ms
# Speed: 5.3ms preprocess, 15.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 16.5ms
# Speed: 4.8ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 21.5ms
# Speed: 3.8ms preprocess, 21.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 16.7ms
# Speed: 2.5ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.7ms
# Speed: 1.1ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.2ms
# Speed: 3.4ms preprocess, 17.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.9ms
# Speed: 0.8ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 13.0ms
# Speed: 2.5ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.4ms
# Speed: 4.2ms preprocess, 19.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.4ms
# Speed: 3.3ms preprocess, 17.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 21.0ms
# Speed: 4.7ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.1ms
# Speed: 3.7ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 12.8ms
# Speed: 4.5ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 16.7ms
# Speed: 2.5ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 17.8ms
# Speed: 4.6ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 11.7ms
# Speed: 2.9ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 25.5ms
# Speed: 3.9ms preprocess, 25.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 22.5ms
# Speed: 4.3ms preprocess, 22.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 23.8ms
# Speed: 5.9ms preprocess, 23.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 13.3ms
# Speed: 2.7ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.8ms
# Speed: 2.7ms preprocess, 14.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 20.3ms
# Speed: 4.3ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 12.6ms
# Speed: 3.8ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 9.9ms
# Speed: 3.2ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 18.8ms
# Speed: 2.9ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 16.0ms
# Speed: 5.1ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 11.9ms
# Speed: 1.6ms preprocess, 11.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 19.3ms
# Speed: 3.1ms preprocess, 19.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 16.1ms
# Speed: 2.4ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 16.9ms
# Speed: 5.2ms preprocess, 16.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 22.1ms
# Speed: 4.1ms preprocess, 22.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 32.5ms
# Speed: 4.0ms preprocess, 32.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.1ms
# Speed: 0.9ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 21.5ms
# Speed: 2.6ms preprocess, 21.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 13.4ms
# Speed: 4.6ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.9ms
# Speed: 0.9ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.1ms
# Speed: 4.3ms preprocess, 19.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 13.0ms
# Speed: 5.0ms preprocess, 13.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.5ms
# Speed: 2.8ms preprocess, 17.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 11.1ms
# Speed: 7.7ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.4ms
# Speed: 1.2ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 19.0ms
# Speed: 3.4ms preprocess, 19.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.6ms
# Speed: 3.6ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 11.0ms
# Speed: 3.4ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.9ms
# Speed: 3.4ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 12.7ms
# Speed: 1.2ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.7ms
# Speed: 3.3ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 21.8ms
# Speed: 4.4ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 18.9ms
# Speed: 3.4ms preprocess, 18.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 16.6ms
# Speed: 4.8ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.1ms
# Speed: 1.2ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 13.9ms
# Speed: 2.5ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 11.8ms
# Speed: 2.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.7ms
# Speed: 7.1ms preprocess, 17.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.8ms
# Speed: 3.5ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 20.8ms
# Speed: 3.8ms preprocess, 20.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 12.9ms
# Speed: 3.6ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 13.4ms
# Speed: 3.2ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 14.3ms
# Speed: 3.2ms preprocess, 14.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 18.5ms
# Speed: 1.8ms preprocess, 18.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 27.6ms
# Speed: 6.0ms preprocess, 27.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 19.6ms
# Speed: 3.6ms preprocess, 19.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 17.9ms
# ...
# Speed: 1.4ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 14.9ms
# Speed: 6.3ms preprocess, 14.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 13.2ms
# Speed: 3.3ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 10.2ms
# Speed: 3.1ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 19.8ms
# Speed: 2.7ms preprocess, 19.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 16.7ms
# Speed: 2.8ms preprocess, 16.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 20.8ms
# Speed: 2.8ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 16.5ms
# Speed: 5.9ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 18.1ms
# Speed: 3.6ms preprocess, 18.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 14.5ms
# Speed: 2.7ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 18.5ms
# Speed: 6.4ms preprocess, 18.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 8.0ms
# Speed: 1.1ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 12.4ms
# Speed: 2.1ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 20.1ms
# Speed: 4.3ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 5.0ms
# Speed: 0.9ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.0ms
# Speed: 4.9ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.3ms
# Speed: 0.9ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 18.9ms
# Speed: 3.4ms preprocess, 18.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 10.2ms
# Speed: 2.9ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 12.4ms
# Speed: 6.0ms preprocess, 12.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 16.7ms
# Speed: 2.8ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 21.6ms
# Speed: 5.7ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 20.7ms
# Speed: 5.0ms preprocess, 20.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 59.0ms
# Speed: 6.7ms preprocess, 59.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 13.4ms
# Speed: 0.7ms preprocess, 13.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 7.9ms
# Speed: 3.4ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.4ms
# Speed: 1.4ms preprocess, 4.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 9.4ms
# Speed: 0.7ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 13.7ms
# Speed: 3.7ms preprocess, 13.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 20.2ms
# Speed: 5.2ms preprocess, 20.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 15.2ms
# Speed: 1.4ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 11.3ms
# Speed: 2.3ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 13.2ms
# Speed: 6.0ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 13.9ms
# Speed: 4.0ms preprocess, 13.9ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 44.6ms
# Speed: 7.1ms preprocess, 44.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.7ms
# Speed: 0.7ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 16.0ms
# Speed: 4.7ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 15.1ms
# Speed: 3.7ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 21.5ms
# Speed: 3.6ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 11.1ms
# Speed: 3.2ms preprocess, 11.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 15.5ms
# Speed: 3.8ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 telecos, 20.4ms
# Speed: 5.4ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 7.3ms
# Speed: 0.9ms preprocess, 7.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 12.4ms
# Speed: 3.9ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 telecos, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 13.7ms
# Speed: 4.0ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 10.1ms
# Speed: 3.1ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 16.3ms
# Speed: 2.5ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[5], line 73
#      70         proc.wait()
#      72 if __name__ == "__main__":
# ---> 73     main()
#
# Cell In[5], line 61, in main()
#      57         cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
#      58         cv2.putText(frame, f"{name} {score:.2f}", (x1, y1-10),
#      59                     cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)
# ---> 61     proc.stdin.write(frame.tobytes())
#      63 cap.release()
#      64 proc.stdin.close()
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# ### Annotate videos with pretrained model

# %%
#!/usr/bin/env python3
import os
import cv2
import json
import sys
from ultralytics import YOLO

# ─── USER CONFIGURATION ─────────────────────────────────────────────────────────
#
#  1) Path to your trained weights (best.pt)
#  2) Path to the video you want to run inference on
#  3) Output directory (e.g. "Video_2") – the script will create this if needed.
#
MODEL_PATH   = "../src/human_detector/models/best.pt"
SOURCE_VIDEO = "converted_mp4_videos/2nd_batch_converted/robots_humans_side_2.mp4"
OUTPUT_DIR   = "labelled_data/robots_humans_side_2"
#                                                                              ──
#  After running this script, you will end up with:
#
#    /home/yogee/Desktop/human_detector_ws/Video_2/
#    ├── obj_train_data/
#    │   ├── frame_000000.png
#    │   ├── frame_000000.txt
#    │   ├── frame_000001.png
#    │   ├── frame_000001.txt
#    │   ├── …
#    │
#    ├── obj.names
#    ├── obj.data
#    └── train.txt
#
#  Which is the exact format Darknet/Yolo expects for “Video_2” if you want to
#  fine-tune on those automatically-generated labels.
# ────────────────────────────────────────────────────────────────────────────────


def create_dirs():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    os.makedirs(os.path.join(OUTPUT_DIR, "obj_train_data"), exist_ok=True)


def write_obj_names(class_names):
    """
    Write the file obj.names in OUTPUT_DIR. Each line is one class name.
    """
    fn = os.path.join(OUTPUT_DIR, "obj.names")
    with open(fn, "w") as f:
        for name in class_names:
            f.write(f"{name}\n")


def write_obj_data(num_classes):
    """
    Write the file obj.data in OUTPUT_DIR:

    classes = <num_classes>
    train = train.txt
    names = obj.names
    backup = backup/
    """
    fn = os.path.join(OUTPUT_DIR, "obj.data")
    with open(fn, "w") as f:
        f.write(f"classes = {num_classes}\n")
        f.write("train = train.txt\n")
        f.write("names = obj.names\n")
        f.write("backup = backup/\n")


def write_train_txt(image_filenames):
    """
    Given a list of image filenames (relative to OUTPUT_DIR), write them into train.txt.
    Example line in train.txt: 
        obj_train_data/frame_000000.png
        obj_train_data/frame_000001.png
        …
    """
    fn = os.path.join(OUTPUT_DIR, "train.txt")
    with open(fn, "w") as f:
        for rel_path in image_filenames:
            f.write(f"{rel_path}\n")


def xyxy_to_yolo(x1, y1, x2, y2, img_w, img_h):
    """
    Convert [x1,y1,x2,y2] to YOLO format:
      x_center = ((x1 + x2)/2) / img_w
      y_center = ((y1 + y2)/2) / img_h
      width    = (x2 - x1) / img_w
      height   = (y2 - y1) / img_h

    Returns a tuple of floats: (x_center, y_center, width, height)
    """
    x_center = ((x1 + x2) / 2.0) / img_w
    y_center = ((y1 + y2) / 2.0) / img_h
    w        = (x2 - x1) / img_w
    h        = (y2 - y1) / img_h
    return x_center, y_center, w, h


def main():
    # 1) Create output directories:
    create_dirs()
    images_folder = os.path.join(OUTPUT_DIR, "obj_train_data")

    # 2) Load the YOLO model once:
    model = YOLO(MODEL_PATH)

    # 3) Open the source video:
    cap = cv2.VideoCapture(SOURCE_VIDEO)
    if not cap.isOpened():
        print(f"❌ ERROR: could not open video file '{SOURCE_VIDEO}'")
        sys.exit(1)

    # 4) Grab video properties:
    frame_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    print(f"Video loaded: {SOURCE_VIDEO}")
    print(f"  → Resolution: {frame_w}×{frame_h}")
    print(f"  → Total frames: {total_frames}\n")

    image_filenames = []

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # 5) Run YOLO inference on this frame
        results = model(frame)[0]

        # 6) Build paths:
        img_name = f"frame_{frame_idx:06d}.png"
        txt_name = f"frame_{frame_idx:06d}.txt"
        img_path = os.path.join(images_folder, img_name)
        txt_path = os.path.join(images_folder, txt_name)

        # 7) Save the raw frame as a PNG:
        cv2.imwrite(img_path, frame)

        # 8) Open the .txt file and write detections (in YOLO .txt format)
        with open(txt_path, "w") as f_txt:
            # results.boxes.xyxy is a tensor of shape (N, 4): [x1, y1, x2, y2]
            boxes   = results.boxes.xyxy.cpu().numpy()  # shape (N, 4)
            confs   = results.boxes.conf.cpu().numpy()  # shape (N,)
            classes = results.boxes.cls.cpu().numpy()   # shape (N,)

            for (x1, y1, x2, y2), conf, cls_idx in zip(boxes, confs, classes):
                # Convert to integers (pixel coords)
                x1_i, y1_i, x2_i, y2_i = map(int, (x1, y1, x2, y2))
                # Convert bounding box to YOLO format (normalized):
                x_c, y_c, w_rel, h_rel = xyxy_to_yolo(x1_i, y1_i, x2_i, y2_i, frame_w, frame_h)

                # Write one line per box: <class_id> <x_center> <y_center> <w> <h>
                # Each value is float. We’ll format to 6 decimal places.
                f_txt.write(f"{int(cls_idx)} {x_c:.6f} {y_c:.6f} {w_rel:.6f} {h_rel:.6f}\n")

        # 9) Keep a record of relative image path for train.txt:
        image_filenames.append(f"obj_train_data/{img_name}")

        if frame_idx % 50 == 0:
            print(f"  Processed frame {frame_idx}/{total_frames} …")

        frame_idx += 1

    cap.release()
    print(f"\n✅ Saved {frame_idx} frames + YOLO‐format .txt labels into '{images_folder}'")

    # 10) Write obj.names (one name per line) using model.names:
    write_obj_names(["person", "teleco"])
    print("✅ Wrote obj.names")

    # 11) Write obj.data (Darknet‐style):
    num_classes = len(model.names)
    write_obj_data(num_classes)
    print("✅ Wrote obj.data")

    # 12) Write train.txt listing all image files under obj_train_data/
    write_train_txt(image_filenames)
    print("✅ Wrote train.txt")

    print("\nAll done! Your directory structure is now:")
    print(f"  {OUTPUT_DIR}/obj_train_data/")
    print(f"    ├─ frame_000000.png")
    print(f"    ├─ frame_000000.txt")
    print(f"    ├─ frame_000001.png")
    print(f"    ├─ frame_000001.txt")
    print(f"    └─ …")
    print(f"\n  {OUTPUT_DIR}/obj.names")
    print(f"  {OUTPUT_DIR}/obj.data")
    print(f"  {OUTPUT_DIR}/train.txt\n")


if __name__ == "__main__":
    main()
# Out:
# Video loaded: converted_mp4_videos/2nd_batch_converted/robots_humans_side_2.mp4
#   → Resolution: 640×480
#   → Total frames: 1421
#
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 0/1421 …
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 0.7ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 6.8ms
# Speed: 0.8ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 5.6ms
# Speed: 1.7ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.9ms
# Speed: 1.0ms preprocess, 5.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 50/1421 …
#
# 0: 480x640 2 persons, 2 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 1.6ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.0ms
# Speed: 0.9ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teleco, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teleco, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 100/1421 …
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 10.7ms
# Speed: 1.1ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.4ms
# Speed: 1.5ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.9ms
# Speed: 0.8ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.9ms
# Speed: 0.8ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.6ms
# Speed: 1.1ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 150/1421 …
#
# 0: 480x640 4 persons, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.8ms
# Speed: 2.1ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 7.3ms
# Speed: 0.8ms preprocess, 7.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 4.6ms
# Speed: 1.4ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.9ms
# Speed: 0.8ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 14.6ms
# Speed: 0.8ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 200/1421 …
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.8ms
# Speed: 0.7ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.9ms
# Speed: 0.8ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 telecos, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.4ms
# Speed: 1.5ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 8.2ms
# Speed: 3.9ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 22.4ms
# Speed: 0.8ms preprocess, 22.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 250/1421 …
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 5.2ms
# Speed: 0.9ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.6ms
# Speed: 0.7ms preprocess, 5.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.4ms
# Speed: 0.9ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.3ms
# Speed: 0.9ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 300/1421 …
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.9ms
# Speed: 0.8ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 5.0ms
# Speed: 0.7ms preprocess, 5.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 telecos, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ...
#
# 0: 480x640 1 person, 4 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.5ms
# Speed: 1.2ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 7.8ms
# Speed: 0.9ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 7.9ms
# Speed: 0.7ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.6ms
# Speed: 4.1ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.9ms
# Speed: 0.7ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 1350/1421 …
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.4ms
# Speed: 1.1ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.8ms
# Speed: 0.7ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.8ms
# Speed: 1.9ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 1400/1421 …
#
# 0: 480x640 1 person, 4 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 8.9ms
# Speed: 0.8ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 4.6ms
# Speed: 1.2ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 4.2ms
# Speed: 1.2ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 telecos, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# ✅ Saved 1421 frames + YOLO‐format .txt labels into 'labelled_data/robots_humans_side_2/obj_train_data'
# ✅ Wrote obj.names
# ✅ Wrote obj.data
# ✅ Wrote train.txt
#
# All done! Your directory structure is now:
#   labelled_data/robots_humans_side_2/obj_train_data/
#     ├─ frame_000000.png
#     ├─ frame_000000.txt
#     ├─ frame_000001.png
#     ├─ frame_000001.txt
#     └─ …
#
#   labelled_data/robots_humans_side_2/obj.names
#   labelled_data/robots_humans_side_2/obj.data
#   labelled_data/robots_humans_side_2/train.txt

# %% [markdown]
# ### Download person dataset

# %%
import os
import json
import requests
import random
from tqdm import tqdm
from pycocotools.coco import COCO
from pathlib import Path
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

from shutil import copyfile

# Set random seed for reproducibility
random.seed(42)

# Define paths
BASE_DIR = '../data_training/data_person'
IMG_DIR_TRAIN = os.path.join(BASE_DIR, 'images/train')
IMG_DIR_VAL = os.path.join(BASE_DIR, 'images/val')
LBL_DIR_TRAIN = os.path.join(BASE_DIR, 'labels/train')
LBL_DIR_VAL = os.path.join(BASE_DIR, 'labels/val')

for d in [IMG_DIR_TRAIN, IMG_DIR_VAL, LBL_DIR_TRAIN, LBL_DIR_VAL]:
    os.makedirs(d, exist_ok=True)

# Load COCO
coco = COCO('../data_training/data_person/annotations/instances_train2017.json')
catIds = coco.getCatIds(catNms=['person'])
imgIds = coco.getImgIds(catIds=catIds)
images = coco.loadImgs(imgIds)

# Split train/val
random.shuffle(images)
split_idx = int(0.9 * len(images))
train_images = images[:split_idx]
val_images = images[split_idx:]

# Retry session for downloads
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# Helper to convert COCO bbox to YOLO
def coco_to_yolo_bbox(bbox, img_w, img_h):
    x, y, w, h = bbox
    x_center = (x + w / 2) / img_w
    y_center = (y + h / 2) / img_h
    return [x_center, y_center, w / img_w, h / img_h]

# Process dataset
def process_dataset(images, img_dir, lbl_dir):
    for img in tqdm(images, desc=f"Processing {img_dir}"):
        file_name = img['file_name']
        img_path = os.path.join(img_dir, file_name)
        label_path = os.path.join(lbl_dir, file_name.replace('.jpg', '.txt'))

        # Download image if not exists
        if not os.path.isfile(img_path):
            try:
                img_data = session.get(img['coco_url']).content
                with open(img_path, 'wb') as f:
                    f.write(img_data)
            except Exception as e:
                print(f"Failed to download {file_name}: {e}")
                continue

        # Get annotations
        annIds = coco.getAnnIds(imgIds=[img['id']], catIds=catIds, iscrowd=False)
        anns = coco.loadAnns(annIds)

        if not anns:
            continue

        with open(label_path, 'w') as f:
            for ann in anns:
                bbox = coco_to_yolo_bbox(ann['bbox'], img['width'], img['height'])
                f.write(f"0 {' '.join([f'{x:.6f}' for x in bbox])}\n")

# Process both sets
process_dataset(train_images, IMG_DIR_TRAIN, LBL_DIR_TRAIN)
process_dataset(val_images, IMG_DIR_VAL, LBL_DIR_VAL)
# Out:
# loading annotations into memory...
# Done (t=8.66s)
# creating index...
# index created!
# Processing ../data_training/data_person/images/train:  21%|██        | 12238/57703 [1:38:30<6:05:56,  2.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 82
#      79                 f.write(f"0 {' '.join([f'{x:.6f}' for x in bbox])}\n")
#      81 # Process both sets
# ---> 82 process_dataset(train_images, IMG_DIR_TRAIN, LBL_DIR_TRAIN)
#      83 process_dataset(val_images, IMG_DIR_VAL, LBL_DIR_VAL)
#
# Cell In[3], line 62, in process_dataset(images, img_dir, lbl_dir)
#      60 if not os.path.isfile(img_path):
#      61     try:
# ---> 62         img_data = session.get(img['coco_url']).content
#      63         with open(img_path, 'wb') as f:
#      64             f.write(img_data)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Split Teleco dataset

# %%
# %% [code]
# 1) (Optional) install PyYAML if you haven't already
# !pip install pyyaml --quiet

import shutil
import random
from pathlib import Path
import yaml

# 2) Define your paths (all relative to your notebook cwd == HUMAN_DETECTOR_WS)
repo_root  = Path().resolve()
export_dir = repo_root / "labelled_data" / "robots_humans_side_2" / "obj_train_data"
names_file = repo_root / "labelled_data" / "robots_humans_side_2" / "obj.names"
dest_dir   = repo_root / "../data_training/data_teleco/robots_humans_side_2"

assert export_dir.exists(), f"Export dir not found: {export_dir}"
assert names_file.exists(), f"Names file not found: {names_file}"

# 3) Create train/val subfolders under training_data/images and training_data/labels
for split in ("train","val"):
    (dest_dir/"images"/split).mkdir(parents=True, exist_ok=True)
    (dest_dir/"labels"/split).mkdir(parents=True, exist_ok=True)

# 4) Gather all image files from the CVAT export
img_exts = {".png", ".jpg", ".jpeg"}
all_imgs = sorted(p for p in export_dir.iterdir() if p.suffix.lower() in img_exts)

# 5) Shuffle & split 80/20
random.seed(42)
random.shuffle(all_imgs)
n_train   = int(0.8 * len(all_imgs))
train_imgs, val_imgs = all_imgs[:n_train], all_imgs[n_train:]

# 6) Copy images and their .txt labels into the training_data folder structure
for split, imgs in [("train", train_imgs), ("val", val_imgs)]:
    for img_path in imgs:
        lbl_path = export_dir / f"{img_path.stem}.txt"
        if not lbl_path.exists():
            print(f"Missing label for: {img_path.name}")
            continue
        shutil.copy2(img_path,   dest_dir/"images"/split/img_path.name)
        shutil.copy2(lbl_path,   dest_dir/"labels"/split/f"{img_path.stem}.txt")

# 7) Read your class names
with open(names_file) as f:
    names = [line.strip() for line in f if line.strip()]

# 8) Write a data.yaml for YOLO training
cfg = {
    "path": str(dest_dir),     # base dir for train/val
    "train": "images/train",
    "val":   "images/val",
    "nc":    len(names),
    "names": names
}
with open(dest_dir/"data.yaml", "w") as f:
    yaml.safe_dump(cfg, f, sort_keys=False)

print(f"✅ Copied {len(train_imgs)} train / {len(val_imgs)} val images")
print(f"✅ data.yaml written to {dest_dir/'data.yaml'}")
# Out:
# ✅ Copied 1136 train / 285 val images
# ✅ data.yaml written to /home/commu/Desktop/human_detector_ws/data_raw/../data_training/data_teleco/robots_humans_side_2/data.yaml
