# %% [markdown]
# ### Convert RealSense .bag → MP4

# %%
import numpy as np
import pyrealsense2 as rs
import cv2

def bag_to_mp4(bag_path: str, out_path: str, fps: float = 30.0):
    """
    Read a RealSense .bag file and write out a color-only MP4.
    """
    pipeline = rs.pipeline()
    cfg = rs.config()
    cfg.enable_device_from_file(bag_path, repeat_playback=False)
    profile = pipeline.start(cfg)

    # get color stream resolution
    color_stream = profile.get_stream(rs.stream.color).as_video_stream_profile()
    w, h = color_stream.width(), color_stream.height()

    # set up VideoWriter (mp4v codec)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(out_path, fourcc, fps, (w, h))

    try:
        while True:
            frames = pipeline.wait_for_frames()
            color = frames.get_color_frame()
            if not color:
                continue
            # convert to numpy array (RGB)
            img_rgb = np.asanyarray(color.get_data())
            # convert RGB→BGR for correct colors in OpenCV
            img_bgr = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR)
            writer.write(img_bgr)
    except RuntimeError:
        # bag playback ended
        pass
    finally:
        writer.release()
        pipeline.stop()
        print(f"✅ Wrote {out_path}")

# %% [markdown]
# ### Run conversion

# %%
import os

input_folder = "ros_bags/2nd_batch"  # replace with your folder containing .bag files
output_folder = "ros_bags/2nd_batch_converted"      # replace with your desired output folder
fps = 30.0                           # set your desired fps

os.makedirs(output_folder, exist_ok=True)

for fname in os.listdir(input_folder):
    if fname.endswith(".bag"):
        bag_file = os.path.join(input_folder, fname)
        output_mp4 = os.path.join(output_folder, os.path.splitext(fname)[0] + ".mp4")
        bag_to_mp4(bag_file, output_mp4, fps)
# Out:
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155234.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155333.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155749.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_153521.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_153723.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_155117.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_154227.mp4
# ✅ Wrote /home/yogee/Desktop/human_detector_ws/data_raw/ros_bags/2nd_batch_converted/20250603_160032.mp4

# %% [markdown]
# ### View annotated Video

# %%
#!/usr/bin/env python3
import cv2
import subprocess
from ultralytics import YOLO
import sys

# ─── ADJUST THESE ───────────────────────────────────────────────────────────────
MODEL_PATH   = "../src/human_detector/models/best.pt"
# MODEL_PATH   = "../src/human_detector/models/best_v2_yolov11n.pt"
SOURCE_VIDEO = "converted_mp4_videos/2nd_batch_converted/robots_vincent_front_simulated.mp4"
# ───────────────────────────────────────────────────────────────────────────────

def main():
    model = YOLO(MODEL_PATH)

    cap = cv2.VideoCapture(SOURCE_VIDEO)
    if not cap.isOpened():
        print(f"Error: cannot open {SOURCE_VIDEO}")
        sys.exit(1)

    fps    = cap.get(cv2.CAP_PROP_FPS) or 25
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    ffplay_cmd = [
        "ffplay",
        "-f", "rawvideo",
        "-pixel_format", "bgr24",
        "-video_size", f"{width}x{height}",
        "-framerate", str(int(fps)),
        "-autoexit",
        "-i", "-"
    ]

    try:
        proc = subprocess.Popen(ffplay_cmd, stdin=subprocess.PIPE, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    except FileNotFoundError:
        print("Error: ffplay not found. Install ffmpeg/ffplay.")
        cap.release()
        sys.exit(1)

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            results = model(frame)[0]
            boxes   = results.boxes.xyxy.cpu().numpy()
            confs   = results.boxes.conf.cpu().numpy()
            classes = results.boxes.cls.cpu().numpy()

            for (x1, y1, x2, y2), conf, cls in zip(boxes, confs, classes):
                x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
                name = model.names[int(cls)]
                score = conf.item()
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
                cv2.putText(frame, f"{name} {score:.2f}", (x1, y1-10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)

            proc.stdin.write(frame.tobytes())

        cap.release()
        proc.stdin.close()
        proc.wait()

    except KeyboardInterrupt:
        cap.release()
        proc.stdin.close()
        proc.wait()

if __name__ == "__main__":
    main()
# Out:
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 1.8ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 13.8ms
# Speed: 4.0ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.3ms
# Speed: 0.9ms preprocess, 7.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.9ms
# Speed: 3.3ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.6ms
# Speed: 1.4ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 19.6ms
# Speed: 2.6ms preprocess, 19.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.6ms
# Speed: 3.6ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.9ms
# Speed: 3.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.7ms
# Speed: 3.3ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 14.2ms
# Speed: 2.7ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 14.0ms
# Speed: 3.6ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 35.2ms
# Speed: 3.8ms preprocess, 35.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 21.2ms
# Speed: 7.4ms preprocess, 21.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.6ms
# Speed: 2.9ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 23.6ms
# Speed: 9.2ms preprocess, 23.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.6ms
# Speed: 1.5ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.4ms
# Speed: 0.9ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 23.4ms
# Speed: 4.2ms preprocess, 23.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 31.4ms
# Speed: 2.3ms preprocess, 31.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 31.9ms
# Speed: 2.2ms preprocess, 31.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.5ms
# Speed: 1.4ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 19.0ms
# Speed: 3.6ms preprocess, 19.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 23.1ms
# Speed: 5.7ms preprocess, 23.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 17.1ms
# Speed: 2.5ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 20.6ms
# Speed: 2.8ms preprocess, 20.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 30.4ms
# Speed: 4.0ms preprocess, 30.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 20.6ms
# Speed: 3.6ms preprocess, 20.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 12.6ms
# Speed: 1.7ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 9.7ms
# Speed: 4.8ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 16.8ms
# Speed: 3.9ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 21.7ms
# Speed: 3.4ms preprocess, 21.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.9ms
# Speed: 3.8ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 18.0ms
# Speed: 4.1ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 16.6ms
# Speed: 3.9ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 12.8ms
# Speed: 2.2ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 21.3ms
# Speed: 4.6ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[11], line 73
#      70         proc.wait()
#      72 if __name__ == "__main__":
# ---> 73     main()
#
# Cell In[11], line 61, in main()
#      57         cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
#      58         cv2.putText(frame, f"{name} {score:.2f}", (x1, y1-10),
#      59                     cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)
# ---> 61     proc.stdin.write(frame.tobytes())
#      63 cap.release()
#      64 proc.stdin.close()
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# ### Annotate videos with pretrained model

# %%
#!/usr/bin/env python3
import os
import cv2
import json
import sys
from ultralytics import YOLO

# ─── USER CONFIGURATION ─────────────────────────────────────────────────────────
#
#  1) Path to your trained weights (best.pt)
#  2) Path to the video you want to run inference on
#  3) Output directory (e.g. "Video_2") – the script will create this if needed.
#
MODEL_PATH   = "../src/human_detector/models/best.pt"
SOURCE_VIDEO = "converted_mp4_videos/2nd_batch_converted/robots_vincent_front_simulated.mp4"
OUTPUT_DIR   = "labelled_data/robots_vincent_front_simulated"
#                                                                              ──
#  After running this script, you will end up with:
#
#    /home/yogee/Desktop/human_detector_ws/Video_2/
#    ├── obj_train_data/
#    │   ├── frame_000000.png
#    │   ├── frame_000000.txt
#    │   ├── frame_000001.png
#    │   ├── frame_000001.txt
#    │   ├── …
#    │
#    ├── obj.names
#    ├── obj.data
#    └── train.txt
#
#  Which is the exact format Darknet/Yolo expects for “Video_2” if you want to
#  fine-tune on those automatically-generated labels.
# ────────────────────────────────────────────────────────────────────────────────


def create_dirs():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    os.makedirs(os.path.join(OUTPUT_DIR, "obj_train_data"), exist_ok=True)


def write_obj_names(class_names):
    """
    Write the file obj.names in OUTPUT_DIR. Each line is one class name.
    """
    fn = os.path.join(OUTPUT_DIR, "obj.names")
    with open(fn, "w") as f:
        for name in class_names:
            f.write(f"{name}\n")


def write_obj_data(num_classes):
    """
    Write the file obj.data in OUTPUT_DIR:

    classes = <num_classes>
    train = train.txt
    names = obj.names
    backup = backup/
    """
    fn = os.path.join(OUTPUT_DIR, "obj.data")
    with open(fn, "w") as f:
        f.write(f"classes = {num_classes}\n")
        f.write("train = train.txt\n")
        f.write("names = obj.names\n")
        f.write("backup = backup/\n")


def write_train_txt(image_filenames):
    """
    Given a list of image filenames (relative to OUTPUT_DIR), write them into train.txt.
    Example line in train.txt: 
        obj_train_data/frame_000000.png
        obj_train_data/frame_000001.png
        …
    """
    fn = os.path.join(OUTPUT_DIR, "train.txt")
    with open(fn, "w") as f:
        for rel_path in image_filenames:
            f.write(f"{rel_path}\n")


def xyxy_to_yolo(x1, y1, x2, y2, img_w, img_h):
    """
    Convert [x1,y1,x2,y2] to YOLO format:
      x_center = ((x1 + x2)/2) / img_w
      y_center = ((y1 + y2)/2) / img_h
      width    = (x2 - x1) / img_w
      height   = (y2 - y1) / img_h

    Returns a tuple of floats: (x_center, y_center, width, height)
    """
    x_center = ((x1 + x2) / 2.0) / img_w
    y_center = ((y1 + y2) / 2.0) / img_h
    w        = (x2 - x1) / img_w
    h        = (y2 - y1) / img_h
    return x_center, y_center, w, h


def main():
    # 1) Create output directories:
    create_dirs()
    images_folder = os.path.join(OUTPUT_DIR, "obj_train_data")

    # 2) Load the YOLO model once:
    model = YOLO(MODEL_PATH)

    # 3) Open the source video:
    cap = cv2.VideoCapture(SOURCE_VIDEO)
    if not cap.isOpened():
        print(f"❌ ERROR: could not open video file '{SOURCE_VIDEO}'")
        sys.exit(1)

    # 4) Grab video properties:
    frame_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    print(f"Video loaded: {SOURCE_VIDEO}")
    print(f"  → Resolution: {frame_w}×{frame_h}")
    print(f"  → Total frames: {total_frames}\n")

    image_filenames = []

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # 5) Run YOLO inference on this frame
        results = model(frame)[0]

        # 6) Build paths:
        img_name = f"frame_{frame_idx:06d}.png"
        txt_name = f"frame_{frame_idx:06d}.txt"
        img_path = os.path.join(images_folder, img_name)
        txt_path = os.path.join(images_folder, txt_name)

        # 7) Save the raw frame as a PNG:
        cv2.imwrite(img_path, frame)

        # 8) Open the .txt file and write detections (in YOLO .txt format)
        with open(txt_path, "w") as f_txt:
            # results.boxes.xyxy is a tensor of shape (N, 4): [x1, y1, x2, y2]
            boxes   = results.boxes.xyxy.cpu().numpy()  # shape (N, 4)
            confs   = results.boxes.conf.cpu().numpy()  # shape (N,)
            classes = results.boxes.cls.cpu().numpy()   # shape (N,)

            for (x1, y1, x2, y2), conf, cls_idx in zip(boxes, confs, classes):
                # Convert to integers (pixel coords)
                x1_i, y1_i, x2_i, y2_i = map(int, (x1, y1, x2, y2))
                # Convert bounding box to YOLO format (normalized):
                x_c, y_c, w_rel, h_rel = xyxy_to_yolo(x1_i, y1_i, x2_i, y2_i, frame_w, frame_h)

                # Write one line per box: <class_id> <x_center> <y_center> <w> <h>
                # Each value is float. We’ll format to 6 decimal places.
                f_txt.write(f"{int(cls_idx)} {x_c:.6f} {y_c:.6f} {w_rel:.6f} {h_rel:.6f}\n")

        # 9) Keep a record of relative image path for train.txt:
        image_filenames.append(f"obj_train_data/{img_name}")

        if frame_idx % 50 == 0:
            print(f"  Processed frame {frame_idx}/{total_frames} …")

        frame_idx += 1

    cap.release()
    print(f"\n✅ Saved {frame_idx} frames + YOLO‐format .txt labels into '{images_folder}'")

    # 10) Write obj.names (one name per line) using model.names:
    write_obj_names(["person", "teleco"])
    print("✅ Wrote obj.names")

    # 11) Write obj.data (Darknet‐style):
    num_classes = len(model.names)
    write_obj_data(num_classes)
    print("✅ Wrote obj.data")

    # 12) Write train.txt listing all image files under obj_train_data/
    write_train_txt(image_filenames)
    print("✅ Wrote train.txt")

    print("\nAll done! Your directory structure is now:")
    print(f"  {OUTPUT_DIR}/obj_train_data/")
    print(f"    ├─ frame_000000.png")
    print(f"    ├─ frame_000000.txt")
    print(f"    ├─ frame_000001.png")
    print(f"    ├─ frame_000001.txt")
    print(f"    └─ …")
    print(f"\n  {OUTPUT_DIR}/obj.names")
    print(f"  {OUTPUT_DIR}/obj.data")
    print(f"  {OUTPUT_DIR}/train.txt\n")


if __name__ == "__main__":
    main()
# Out:
# Video loaded: converted_mp4_videos/2nd_batch_converted/robots_vincent_front_simulated.mp4
#   → Resolution: 640×480
#   → Total frames: 669
#
#
# 0: 480x640 1 person, 2 telecos, 4.7ms
# Speed: 2.2ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 0/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.2ms
# Speed: 0.9ms preprocess, 6.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.4ms
# Speed: 0.7ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 50/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.2ms
# Speed: 0.7ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 100/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.7ms
# Speed: 0.7ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.7ms
# Speed: 0.7ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 150/669 …
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.6ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.6ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.6ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.6ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.6ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.6ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 200/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 12.9ms
# Speed: 1.7ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 250/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.5ms
# Speed: 1.1ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 1.0ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.6ms
# Speed: 0.8ms preprocess, 5.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 300/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 11.0ms
# Speed: 0.9ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.4ms
# Speed: 0.8ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 1.0ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 350/669 …
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.2ms
# ...
#   Processed frame 550/669 …
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 telecos, 3.8ms
# Speed: 0.7ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 600/669 …
#
# 0: 480x640 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.9ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 7.7ms
# Speed: 3.2ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 4.4ms
# Speed: 0.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.7ms
# Speed: 0.7ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 telecos, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 43.2ms
# Speed: 4.0ms preprocess, 43.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.3ms
# Speed: 0.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#   Processed frame 650/669 …
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.1ms
# Speed: 0.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.9ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 3.9ms
# Speed: 0.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 telecos, 4.0ms
# Speed: 0.7ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ✅ Saved 669 frames + YOLO‐format .txt labels into 'labelled_data/robots_vincent_front_simulated/obj_train_data'
# ✅ Wrote obj.names
# ✅ Wrote obj.data
# ✅ Wrote train.txt
#
# All done! Your directory structure is now:
#   labelled_data/robots_vincent_front_simulated/obj_train_data/
#     ├─ frame_000000.png
#     ├─ frame_000000.txt
#     ├─ frame_000001.png
#     ├─ frame_000001.txt
#     └─ …
#
#   labelled_data/robots_vincent_front_simulated/obj.names
#   labelled_data/robots_vincent_front_simulated/obj.data
#   labelled_data/robots_vincent_front_simulated/train.txt

# %% [markdown]
# ### Split Teleco dataset

# %%
# %% [code]
# 1) (Optional) install PyYAML if you haven't already
# !pip install pyyaml --quiet

import shutil
import random
from pathlib import Path
import yaml

# 2) Define your paths (all relative to your notebook cwd == HUMAN_DETECTOR_WS)
repo_root  = Path().resolve()
export_dir = repo_root / "labelled_data" / "Video_2" / "obj_train_data"
names_file = repo_root / "labelled_data" / "Video_2" / "obj.names"
dest_dir   = repo_root / "../data_training/data_teleco/Video_2"

assert export_dir.exists(), f"Export dir not found: {export_dir}"
assert names_file.exists(), f"Names file not found: {names_file}"

# 3) Create train/val subfolders under training_data/images and training_data/labels
for split in ("train","val"):
    (dest_dir/"images"/split).mkdir(parents=True, exist_ok=True)
    (dest_dir/"labels"/split).mkdir(parents=True, exist_ok=True)

# 4) Gather all image files from the CVAT export
img_exts = {".png", ".jpg", ".jpeg"}
all_imgs = sorted(p for p in export_dir.iterdir() if p.suffix.lower() in img_exts)

# 5) Shuffle & split 80/20
random.seed(42)
random.shuffle(all_imgs)
n_train   = int(0.8 * len(all_imgs))
train_imgs, val_imgs = all_imgs[:n_train], all_imgs[n_train:]

# 6) Copy images and their .txt labels into the training_data folder structure
for split, imgs in [("train", train_imgs), ("val", val_imgs)]:
    for img_path in imgs:
        lbl_path = export_dir / f"{img_path.stem}.txt"
        if not lbl_path.exists():
            print(f"Missing label for: {img_path.name}")
            continue
        shutil.copy2(img_path,   dest_dir/"images"/split/img_path.name)
        shutil.copy2(lbl_path,   dest_dir/"labels"/split/f"{img_path.stem}.txt")

# 7) Read your class names
with open(names_file) as f:
    names = [line.strip() for line in f if line.strip()]

# 8) Write a data.yaml for YOLO training
cfg = {
    "path": str(dest_dir),     # base dir for train/val
    "train": "images/train",
    "val":   "images/val",
    "nc":    len(names),
    "names": names
}
with open(dest_dir/"data.yaml", "w") as f:
    yaml.safe_dump(cfg, f, sort_keys=False)

print(f"✅ Copied {len(train_imgs)} train / {len(val_imgs)} val images")
print(f"✅ data.yaml written to {dest_dir/'data.yaml'}")
# Out:
# ✅ Copied 1251 train / 313 val images
# ✅ data.yaml written to /home/yogee/Desktop/human_detector_ws/data_raw/../data_training/data_teleco/Video_2/data.yaml
